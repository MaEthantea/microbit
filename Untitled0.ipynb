# %% [markdown]
# <a href="https://colab.research.google.com/github/MaEthantea/microbit/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

display(HTML("""
<style>
    .jp-Notebook, .adab-editor-area, .adab-cell-container {
        background-color: lightblue !important;
    }
</style>
"""))
# Out:
# <style>
#     .jp-Notebook, .adab-editor-area, .adab-cell-container {
#         background-color: lightblue !important;
#     }
# </style>
